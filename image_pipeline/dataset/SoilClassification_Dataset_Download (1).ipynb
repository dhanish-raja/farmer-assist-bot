# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-a45be8b1-50f8-4d4e-9233-0e8d044d0c70" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a45be8b1-50f8-4d4e-9233-0e8d044d0c70">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d ai4a-lab/comprehensive-soil-classification-datasets
# Out:
# Dataset URL: https://www.kaggle.com/datasets/ai4a-lab/comprehensive-soil-classification-datasets
# License(s): CC-BY-NC-SA-4.0
# ...
#  92% 451M/490M [00:03<00:00, 153MB/s]
# 100% 490M/490M [00:03<00:00, 142MB/s]

# %%
# !unzip comprehensive-soil-classification-datasets.zip -d "/content/drive/MyDrive/Chatbot/SoilClassificationDataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/drive/MyDrive/Chatbot/SoilClassificationDataset/CyAUG-Dataset/Black_Soil/b (1053).jpeg
#   inflating: /content/drive/MyDrive/Chatbot/SoilClassificationDataset/CyAUG-Dataset/Black_Soil/b (1054).jpeg
#   inflating: /content/drive/MyDrive/Chatbot/SoilClassificationDataset/CyAUG-Dataset/Black_Soil/b (1055).jpeg
#   inflating: /content/drive/MyDrive/Chatbot/SoilClassificationDataset/CyAUG-Dataset/Black_Soil/b (1056).jpeg
#   inflating: /content/drive/MyDrive/Chatbot/SoilClassificationDataset/CyAUG-Dataset/Black_Soil/b (1057).jpeg
#   inflating: /content/drive/MyDrive/Chatbot/SoilClassificationDataset/CyAUG-Dataset/Black_Soil/b (1058).jpeg
#   inflating: /content/drive/MyDrive/Chatbot/SoilClassificationDataset/CyAUG-Dataset/Black_Soil/b (1059).jpeg
#   inflating: /content/drive/MyDrive/Chatbot/SoilClassificationDataset/CyAUG-Dataset/Black_Soil/b (1060).jpeg
# ...

# %%
# !ls "/content/drive/MyDrive/Chatbot/SoilClassificationDataset"
# Out:
# Alluvial_Soil  Black_Soil     Laterite_Soil  Orignal-Dataset  Yellow_Soil
# Arid_Soil      CyAUG-Dataset  Mountain_Soil  Red_Soil

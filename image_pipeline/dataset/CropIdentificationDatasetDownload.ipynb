# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install kaggle

# %%
from google.colab import files
files.upload()   # Upload kaggle.json here
# Out:
#      <input type="file" id="files-1affb6a0-b9a5-42f3-b625-0ad86c42a68c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1affb6a0-b9a5-42f3-b625-0ad86c42a68c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d osamajalilhassan/agriculture-crops-dataset \
-p "/content/drive/MyDrive/Crop Identification"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/osamajalilhassan/agriculture-crops-dataset
# License(s): unknown
# ...
#  67% 53.0M/79.0M [00:00<00:00, 282MB/s]
# 100% 79.0M/79.0M [00:00<00:00, 281MB/s]

# %%
# !unzip "/content/drive/MyDrive/Crop Identification/agriculture-crops-dataset.zip" \
-d "/content/drive/MyDrive/Crop Identification/"
# Out:
# Archive:  /content/drive/MyDrive/Crop Identification/agriculture-crops-dataset.zip
#   inflating: /content/drive/MyDrive/Crop Identification/Agricultural-crops/Cherry/image15.jpeg
#   inflating: /content/drive/MyDrive/Crop Identification/Agricultural-crops/Cherry/image16.jpeg
#   inflating: /content/drive/MyDrive/Crop Identification/Agricultural-crops/Cherry/image17.jpeg
#   inflating: /content/drive/MyDrive/Crop Identification/Agricultural-crops/Cherry/image18.jpeg
#   inflating: /content/drive/MyDrive/Crop Identification/Agricultural-crops/Cherry/image20.jpeg
#   inflating: /content/drive/MyDrive/Crop Identification/Agricultural-crops/Cherry/image21.jpeg
#   inflating: /content/drive/MyDrive/Crop Identification/Agricultural-crops/Cherry/image22.jpeg
#   inflating: /content/drive/MyDrive/Crop Identification/Agricultural-crops/Cherry/image24.jpeg
#   inflating: /content/drive/MyDrive/Crop Identification/Agricultural-crops/Cherry/image25.jpeg
# ...
